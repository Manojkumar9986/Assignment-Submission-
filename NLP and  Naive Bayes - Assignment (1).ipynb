# %% [markdown]
# 1. Data Exploration and Preprocessing
# •	Load the "blogs_categories.csv" dataset and perform an exploratory data analysis to understand its structure and content.
# •	Preprocess the data by cleaning the text (removing punctuation, converting to lowercase, etc.), tokenizing, and removing stopwords.
# •	Perform feature extraction to convert text data into a format that can be used by the Naive Bayes model, using techniques such as TF-IDF.

# %%
import pandas as pd
nlp = pd.read_csv('blogs (1).csv')
nlp
# Out:
#                                                    Data              Labels
# 0     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 1     Newsgroups: alt.atheism\nPath: cantaloupe.srv....         alt.atheism
# 2     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...         alt.atheism
# 3     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 4     Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...         alt.atheism
# ...                                                 ...                 ...
# 1995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...  talk.religion.misc
# 1996  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1997  Xref: cantaloupe.srv.cs.cmu.edu talk.origins:4...  talk.religion.misc
# 1998  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1999  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...  talk.religion.misc
#
# [2000 rows x 2 columns]

# %%
nlp = data.iloc[:,1:]
nlp
# Out:
#                   Labels
# 0            alt.atheism
# 1            alt.atheism
# 2            alt.atheism
# 3            alt.atheism
# 4            alt.atheism
# ...                  ...
# 1995  talk.religion.misc
# 1996  talk.religion.misc
# 1997  talk.religion.misc
# 1998  talk.religion.misc
# 1999  talk.religion.misc
#
# [2000 rows x 1 columns]

# %%
nlp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Labels  2000 non-null   object
# dtypes: object(1)
# memory usage: 15.8+ KB

# %%
len(nlp['Labels'].unique())
# Out:
# 20

# %%
len(data['Data'].unique())
# Out:
# 2000

# %%
nlp.duplicated().sum()
# Out:
# 1980

# %%
nlp = data.drop_duplicates()
nlp
# Out:
#                                                    Data              Labels
# 0     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 1     Newsgroups: alt.atheism\nPath: cantaloupe.srv....         alt.atheism
# 2     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...         alt.atheism
# 3     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 4     Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...         alt.atheism
# ...                                                 ...                 ...
# 1995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...  talk.religion.misc
# 1996  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1997  Xref: cantaloupe.srv.cs.cmu.edu talk.origins:4...  talk.religion.misc
# 1998  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1999  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...  talk.religion.misc
#
# [2000 rows x 2 columns]

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: nltk in c:\users\bhavana\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bhavana\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\bhavana\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\bhavana\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: click in c:\users\bhavana\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\bhavana\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BHAVANA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\BHAVANA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#from sklearn.feature_extraction.text import TfidfVectorizer

# Download NLTK data files (run this once)
import nltk
# nltk.download('punkt')
# nltk.download('stopwords')

# Function to clean text
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    tokens = word_tokenize(text)  # Tokenize the text
    stop_words = set(stopwords.words('english'))  # Load stopwords
    filtered_tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return ' '.join(filtered_tokens)

# Apply preprocessing
nlp['cleaned_text'] = nlp['Data'].apply(preprocess_text)
nlp['cleaned_text']
# Out:
# 0       path cantaloupesrvcscmuedumagnesiumclubcccmued...
# 1       newsgroups altatheism path cantaloupesrvcscmue...
# 2       path cantaloupesrvcscmuedudasnewsharvardedunoc...
# 3       path cantaloupesrvcscmuedumagnesiumclubcccmued...
# 4       xref cantaloupesrvcscmuedu altatheism53485 tal...
#                               ...
# 1995    xref cantaloupesrvcscmuedu talkabortion120945 ...
# 1996    xref cantaloupesrvcscmuedu talkreligionmisc837...
# 1997    xref cantaloupesrvcscmuedu talkorigins41030 ta...
# 1998    xref cantaloupesrvcscmuedu talkreligionmisc836...
# 1999    xref cantaloupesrvcscmuedu sciskeptic43561 tal...
# Name: cleaned_text, Length: 2000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer()
x= tfidf_vectorizer.fit_transform(data['cleaned_text'])

# The labels for classification
y = nlp['Labels']
x,y
# Out:
# (<2000x56432 sparse matrix of type '<class 'numpy.float64'>'
#  	with 268023 stored elements in Compressed Sparse Row format>,
#  0              alt.atheism
#  1              alt.atheism
#  2              alt.atheism
#  3              alt.atheism
#  4              alt.atheism
#                 ...
#  1995    talk.religion.misc
#  1996    talk.religion.misc
#  1997    talk.religion.misc
#  1998    talk.religion.misc
#  1999    talk.religion.misc
#  Name: Labels, Length: 2000, dtype: object)

# %% [markdown]
# 2. Naive Bayes Model for Text Classification
# •	Split the data into training and test sets.
# •	Implement a Naive Bayes classifier to categorize the blog posts into their respective categories. You can use libraries like scikit-learn for this purpose.
# •	Train the model on the training set and make predictions on the test set.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.naive_bayes import MultinomialNB

# Initialize the classifier
nb_classifier = MultinomialNB()

# Train the model
nb_classifier.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions
y_pred = nb_classifier.predict(x_test)
y_pred
# Out:
# array(['comp.sys.mac.hardware', 'sci.crypt', 'sci.crypt', 'rec.autos',
#        'talk.politics.mideast', 'sci.crypt', 'soc.religion.christian',
#        'soc.religion.christian', 'talk.politics.misc', 'alt.atheism',
#        'sci.electronics', 'soc.religion.christian',
#        'comp.os.ms-windows.misc', 'comp.graphics', 'rec.autos',
#        'talk.politics.misc', 'comp.sys.mac.hardware',
#        'talk.religion.misc', 'soc.religion.christian',
#        'comp.sys.ibm.pc.hardware', 'alt.atheism', 'sci.electronics',
#        'rec.autos', 'soc.religion.christian', 'rec.sport.hockey',
#        'sci.med', 'comp.sys.mac.hardware', 'sci.crypt', 'sci.crypt',
#        'talk.politics.guns', 'sci.electronics', 'sci.crypt',
#        'soc.religion.christian', 'talk.politics.mideast',
#        'rec.sport.hockey', 'comp.sys.mac.hardware', 'rec.sport.hockey',
#        'comp.graphics', 'comp.sys.ibm.pc.hardware', 'rec.sport.baseball',
#        'alt.atheism', 'sci.med', 'sci.electronics', 'alt.atheism',
#        'talk.politics.guns', 'comp.graphics', 'comp.sys.ibm.pc.hardware',
#        'comp.os.ms-windows.misc', 'talk.politics.mideast', 'sci.crypt',
#        'soc.religion.christian', 'sci.med', 'talk.religion.misc',
#        'comp.windows.x', 'comp.os.ms-windows.misc', 'rec.sport.baseball',
#        'comp.sys.mac.hardware', 'talk.politics.mideast',
#        'rec.sport.hockey', 'soc.religion.christian', 'rec.motorcycles',
#        'soc.religion.christian', 'sci.crypt', 'sci.med',
#        'soc.religion.christian', 'rec.autos', 'rec.sport.baseball',
#        'sci.electronics', 'comp.windows.x', 'comp.sys.ibm.pc.hardware',
#        'comp.os.ms-windows.misc', 'rec.motorcycles', 'talk.politics.misc',
#        'talk.politics.mideast', 'comp.sys.ibm.pc.hardware',
#        'talk.politics.guns', 'comp.graphics', 'comp.graphics',
#        'talk.politics.mideast', 'soc.religion.christian',
#        'rec.sport.baseball', 'comp.graphics', 'comp.sys.ibm.pc.hardware',
#        'sci.crypt', 'talk.politics.guns', 'comp.os.ms-windows.misc',
#        'talk.politics.mideast', 'comp.os.ms-windows.misc',
#        'comp.sys.mac.hardware', 'comp.sys.ibm.pc.hardware',
#        'soc.religion.christian', 'rec.sport.hockey', 'comp.graphics',
#        'sci.space', 'soc.religion.christian', 'talk.religion.misc',
#        'soc.religion.christian', 'alt.atheism', 'talk.politics.guns',
#        'comp.os.ms-windows.misc', 'talk.politics.misc', 'sci.electronics',
#        'comp.windows.x', 'soc.religion.christian', 'alt.atheism',
#        'rec.motorcycles', 'sci.crypt', 'talk.politics.guns',
#        'comp.graphics', 'rec.motorcycles', 'comp.sys.ibm.pc.hardware',
#        'talk.politics.guns', 'rec.sport.baseball', 'rec.sport.hockey',
#        'soc.religion.christian', 'misc.forsale', 'talk.religion.misc',
#        'alt.atheism', 'misc.forsale', 'alt.atheism', 'rec.motorcycles',
#        'alt.atheism', 'rec.sport.hockey', 'comp.graphics',
#        'talk.politics.guns', 'sci.crypt', 'rec.sport.baseball',
#        'misc.forsale', 'rec.autos', 'sci.crypt', 'rec.motorcycles',
#        'comp.graphics', 'comp.os.ms-windows.misc',
#        'comp.os.ms-windows.misc', 'talk.politics.misc',
#        'comp.sys.mac.hardware', 'rec.sport.baseball',
#        'comp.os.ms-windows.misc', 'rec.autos', 'comp.sys.ibm.pc.hardware',
#        'talk.politics.guns', 'rec.autos', 'sci.space', 'comp.windows.x',
#        'alt.atheism', 'misc.forsale', 'comp.sys.ibm.pc.hardware',
#        'comp.graphics', 'talk.politics.mideast', 'talk.politics.mideast',
#        'misc.forsale', 'talk.politics.guns', 'comp.windows.x',
#        'talk.politics.guns', 'alt.atheism', 'rec.autos',
#        'comp.os.ms-windows.misc', 'rec.sport.baseball', 'comp.windows.x',
#        'sci.med', 'talk.politics.mideast', 'talk.politics.misc',
#        'sci.crypt', 'sci.med', 'talk.religion.misc', 'rec.sport.baseball',
#        'talk.politics.guns', 'talk.politics.misc', 'rec.autos',
#        'rec.sport.hockey', 'comp.windows.x', 'sci.space',
#        'comp.sys.ibm.pc.hardware', 'comp.graphics', 'comp.windows.x',
#        'talk.religion.misc', 'misc.forsale', 'comp.sys.ibm.pc.hardware',
#        'talk.politics.mideast', 'comp.os.ms-windows.misc', 'sci.space',
#        'soc.religion.christian', 'alt.atheism', 'comp.os.ms-windows.misc',
#        'talk.politics.guns', 'sci.med', 'soc.religion.christian',
#        'comp.sys.mac.hardware', 'comp.os.ms-windows.misc',
#        'talk.religion.misc', 'sci.space', 'misc.forsale',
#        'comp.sys.ibm.pc.hardware', 'comp.windows.x', 'rec.motorcycles',
#        'sci.med', 'talk.religion.misc', 'comp.sys.ibm.pc.hardware',
#        'sci.crypt', 'talk.politics.guns', 'rec.sport.hockey',
#        'comp.sys.mac.hardware', 'comp.sys.mac.hardware',
#        'rec.sport.baseball', 'sci.med', 'comp.sys.ibm.pc.hardware',
#        'talk.politics.guns', 'talk.politics.guns',
#        'comp.sys.ibm.pc.hardware', 'sci.med', 'comp.os.ms-windows.misc',
#        'rec.autos', 'misc.forsale', 'sci.crypt',
#        'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'sci.space',
#        'comp.os.ms-windows.misc', 'sci.med', 'misc.forsale',
#        'comp.sys.mac.hardware', 'rec.autos', 'rec.motorcycles',
#        'comp.windows.x', 'comp.graphics', 'talk.politics.guns',
#        'talk.religion.misc', 'talk.politics.mideast',
#        'comp.sys.mac.hardware', 'talk.politics.guns', 'misc.forsale',
#        'talk.religion.misc', 'talk.politics.mideast',
#        'soc.religion.christian', 'talk.politics.mideast', 'sci.crypt',
#        'sci.crypt', 'soc.religion.christian', 'misc.forsale',
#        'talk.politics.misc', 'comp.windows.x', 'comp.windows.x',
#        'rec.sport.baseball', 'rec.sport.baseball', 'misc.forsale',
#        'comp.sys.ibm.pc.hardware', 'comp.sys.ibm.pc.hardware',
#        'comp.sys.ibm.pc.hardware', 'rec.motorcycles', 'comp.graphics',
#        'talk.religion.misc', 'talk.politics.mideast',
#        'talk.politics.mideast', 'talk.politics.guns',
#        'talk.politics.mideast', 'alt.atheism', 'talk.politics.misc',
#        'talk.politics.guns', 'misc.forsale', 'comp.os.ms-windows.misc',
#        'rec.sport.hockey', 'alt.atheism', 'comp.windows.x', 'sci.crypt',
#        'comp.windows.x', 'sci.electronics', 'sci.electronics',
#        'alt.atheism', 'talk.politics.guns', 'talk.politics.mideast',
#        'comp.windows.x', 'rec.autos', 'rec.motorcycles', 'misc.forsale',
#        'comp.windows.x', 'rec.sport.hockey', 'rec.autos',
#        'comp.os.ms-windows.misc', 'talk.politics.guns',
#        'rec.sport.hockey', 'sci.space', 'sci.crypt',
#        'soc.religion.christian', 'comp.graphics', 'rec.sport.hockey',
#        'misc.forsale', 'rec.autos', 'misc.forsale', 'sci.med',
#        'talk.religion.misc', 'comp.graphics', 'talk.politics.guns',
#        'sci.electronics', 'comp.os.ms-windows.misc', 'rec.sport.baseball',
#        'comp.windows.x', 'rec.sport.baseball', 'rec.autos', 'sci.space',
#        'rec.motorcycles', 'sci.space', 'rec.sport.hockey',
#        'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware',
#        'sci.electronics', 'talk.religion.misc',
#        'comp.sys.ibm.pc.hardware', 'comp.sys.ibm.pc.hardware',
#        'talk.politics.mideast', 'talk.politics.mideast',
#        'talk.politics.misc', 'rec.sport.hockey', 'talk.religion.misc',
#        'rec.sport.hockey', 'talk.politics.guns', 'rec.sport.baseball',
#        'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'sci.space',
#        'talk.politics.guns', 'comp.sys.mac.hardware', 'sci.space',
#        'alt.atheism', 'alt.atheism', 'talk.politics.mideast',
#        'soc.religion.christian', 'rec.motorcycles', 'sci.space',
#        'sci.med', 'talk.religion.misc', 'sci.electronics',
#        'talk.politics.mideast', 'talk.politics.guns', 'rec.sport.hockey',
#        'rec.motorcycles', 'comp.os.ms-windows.misc', 'rec.autos',
#        'comp.sys.ibm.pc.hardware', 'sci.space', 'comp.graphics',
#        'soc.religion.christian', 'sci.med', 'rec.autos', 'sci.crypt',
#        'rec.autos', 'talk.religion.misc', 'talk.politics.misc',
#        'soc.religion.christian', 'soc.religion.christian',
#        'rec.sport.baseball', 'alt.atheism', 'talk.politics.misc',
#        'sci.space', 'rec.autos', 'rec.sport.baseball', 'sci.crypt',
#        'sci.electronics', 'talk.religion.misc', 'alt.atheism',
#        'rec.autos', 'sci.space', 'comp.sys.mac.hardware',
#        'sci.electronics', 'rec.sport.hockey', 'comp.sys.ibm.pc.hardware',
#        'sci.space', 'talk.religion.misc', 'comp.sys.ibm.pc.hardware',
#        'comp.sys.ibm.pc.hardware', 'sci.space',
#        'comp.sys.ibm.pc.hardware', 'rec.motorcycles',
#        'comp.sys.ibm.pc.hardware', 'rec.autos', 'sci.med',
#        'soc.religion.christian', 'comp.sys.mac.hardware',
#        'comp.sys.mac.hardware', 'sci.crypt', 'comp.graphics',
#        'rec.motorcycles', 'comp.sys.mac.hardware', 'alt.atheism',
#        'sci.crypt', 'rec.motorcycles', 'sci.med', 'sci.electronics',
#        'comp.windows.x', 'sci.med', 'talk.politics.mideast',
#        'comp.os.ms-windows.misc', 'soc.religion.christian', 'sci.crypt',
#        'sci.med', 'sci.med', 'misc.forsale', 'sci.electronics',
#        'talk.politics.misc', 'talk.politics.mideast', 'misc.forsale'],
#       dtype='<U24')

# %% [markdown]
# 3. Sentiment Analysis
# •	Choose a suitable library or method for performing sentiment analysis on the blog post texts.
# •	Analyze the sentiments expressed in the blog posts and categorize them as positive, negative, or neutral. Consider only the Data column and get the sentiment for each blog.
# •	Examine the distribution of sentiments across different categories and summarize your findings.

# %%
# !pip install textblob
from textblob import TextBlob

# Function to get sentiment
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

# Apply sentiment analysis
nlp['sentiment'] = nlp['cleaned_text'].apply(get_sentiment)

# Display sentiment distribution
print(nlp['sentiment'].value_counts())
# Out:
# Requirement already satisfied: textblob in c:\users\bhavana\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\bhavana\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: joblib in c:\users\bhavana\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: click in c:\users\bhavana\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bhavana\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\bhavana\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\bhavana\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# positive    1451
# negative     546
# neutral        3
# Name: sentiment, dtype: int64

# %%
nlp
# Out:
#                                                    Data              Labels  \
# 0     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 1     Newsgroups: alt.atheism\nPath: cantaloupe.srv....         alt.atheism
# 2     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...         alt.atheism
# 3     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 4     Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...         alt.atheism
# ...                                                 ...                 ...
# 1995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...  talk.religion.misc
# 1996  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1997  Xref: cantaloupe.srv.cs.cmu.edu talk.origins:4...  talk.religion.misc
# 1998  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1999  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...  talk.religion.misc
#
#                                            cleaned_text sentiment
# 0     path cantaloupesrvcscmuedumagnesiumclubcccmued...  positive
# 1     newsgroups altatheism path cantaloupesrvcscmue...  negative
# 2     path cantaloupesrvcscmuedudasnewsharvardedunoc...  positive
# 3     path cantaloupesrvcscmuedumagnesiumclubcccmued...  positive
# 4     xref cantaloupesrvcscmuedu altatheism53485 tal...  positive
# ...                                                 ...       ...
# 1995  xref cantaloupesrvcscmuedu talkabortion120945 ...  positive
# 1996  xref cantaloupesrvcscmuedu talkreligionmisc837...  positive
# 1997  xref cantaloupesrvcscmuedu talkorigins41030 ta...  positive
# 1998  xref cantaloupesrvcscmuedu talkreligionmisc836...  positive
# 1999  xref cantaloupesrvcscmuedu sciskeptic43561 tal...  positive
#
# [2000 rows x 4 columns]

# %%
# Calculate evaluation metrics
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.85      0.61      0.71        28
#            comp.graphics       0.83      0.83      0.83        18
#  comp.os.ms-windows.misc       0.96      0.92      0.94        24
# comp.sys.ibm.pc.hardware       0.53      0.89      0.67        18
#    comp.sys.mac.hardware       0.72      0.68      0.70        19
#           comp.windows.x       1.00      0.82      0.90        22
#             misc.forsale       0.72      0.81      0.76        16
#                rec.autos       1.00      1.00      1.00        21
#          rec.motorcycles       1.00      0.89      0.94        18
#       rec.sport.baseball       0.94      1.00      0.97        16
#         rec.sport.hockey       1.00      1.00      1.00        18
#                sci.crypt       0.92      1.00      0.96        22
#          sci.electronics       0.93      0.64      0.76        22
#                  sci.med       1.00      0.86      0.93        22
#                sci.space       1.00      1.00      1.00        17
#   soc.religion.christian       0.63      1.00      0.77        17
#       talk.politics.guns       0.81      1.00      0.89        21
#    talk.politics.mideast       0.88      0.91      0.89        23
#       talk.politics.misc       0.69      0.53      0.60        17
#       talk.religion.misc       0.61      0.52      0.56        21
#
#                 accuracy                           0.84       400
#                macro avg       0.85      0.85      0.84       400
#             weighted avg       0.86      0.84      0.84       400

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

acc_score = accuracy_score(y_test,y_pred)
print('accuracy_score : ',acc_score)

prec_score = precision_score(y_test,y_pred , average = 'macro')
print('precision_score :',prec_score)

reca_score = recall_score(y_test,y_pred , average = 'macro')
print('recall_score : ',reca_score)

f_one_score = f1_score(y_test,y_pred ,average = 'macro')
print('f1_score : ', f_one_score)
# Out:
# accuracy_score :  0.84
# precision_score : 0.8512275030785261
# recall_score :  0.845803887309726
# f1_score :  0.8393478607501523

# %% [markdown]
#  # conclusion
#
# 1. The model trained good
# 2. The prediction with respect to testing data ,score is almost 90%
# 3. Sentiment analysis adds another layer of understanding, revealing the emotional tone of the blog posts. These insights can be crucial for content strategy, reader engagement, and marketing efforts.
# 4. By combining text classification with sentiment analysis, you gain a powerful toolkit for extracting and leveraging insights from textual data, enhancing both the analytical and strategic capabilities of your organization.
